# %%
import pandas as pd
import matplotlib.pyplot as plt

df = df = pd.read_csv('/Users/shinten/Desktop/space_econometrics/figures/data/boeing_practice.csv')

# %%
df.plot(x='YEAR', y='PRICE', title='YEAR vs PRICE', legend=True)
plt.xlabel('YEAR')
plt.ylabel('PRICE')
plt.show()

# %%
df.plot(x='YEAR', y='EMPLOYEES', title='YEAR vs EMPLOYEES', legend=True)
plt.xlabel('YEAR')
plt.ylabel('EMPLOYEES')
plt.show()
